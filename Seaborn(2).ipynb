# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
diamond = pd.read_csv('C:\\Users\\test\\Desktop\\Data\\diamonds.csv')

# %%
sns.lmplot(x='carat',y='price',data=diamond)

# %%
diamond1 = diamond.head(100)

# %%
sns.lmplot(x='price',y='carat',data=diamond1)

# %%
diamond1
# Out:
#     Diamonds  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 5          6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 6          7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# 7          8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
# 8          9   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78
# 9         10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05
# 10        11   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28
# ...

# %%
sns.lmplot(x='price',y='carat',data=diamond1,hue='cut',palette='Set2')
xlim=((-20,20))

# %%
sns.lmplot(x='price',y='carat',data=diamond1,hue='color',palette='Set2')
xlim=((-20,20))

# %%
sns.lmplot(x='price',y='carat',data=diamond1,col='cut')
xlim=((-20,20))

# %%
sns.residplot(x='price',y='carat',data=diamond1,color='indianred')

# %%
sns.stripplot(x='carat',y='price',data=diamond1)

# %%
diamond2 = diamond.head(75)

# %%
sns.stripplot(x='price',y='cut',data=diamond2)

# %%
sns.stripplot(x='price',y='clarity',data=diamond2,size=4,jitter=True)

# %%
sns.swarmplot(x='price',y='cut',data=diamond2)

# %%
sns.swarmplot(x='price',y='cut',data=diamond2,hue='clarity')

# %%
sns.swarmplot(x='cut',y='price',data=diamond2,hue='clarity',orient='h')
# Out:
# c:\users\test\appdata\local\programs\python\python36\lib\site-packages\seaborn\categorical.py:1232: RuntimeWarning: invalid value encountered in sqrt
#   dx = np.sqrt(d ** 2 - dy ** 2) * 1.05

# %%
sns.boxplot(x='cut',y='price',data=diamond2)

# %%
sns.violinplot(x='cut',y='price',data=diamond2)

# %%
sns.violinplot(x='cut',y='price',data=diamond2,inner=None,color='lightgrey')
sns.stripplot(x='cut',y='price',data=diamond2,size=4,jitter=True)

# %%
sns.jointplot(x='price',y='carat',data=diamond2)

# %%
sns.jointplot(x='price',y='carat',data=diamond2,kind='kde')

# %%
sns.pairplot(diamond2)

# %%
sns.pairplot(diamond2,hue='carat')

# %%
diamond2
# Out:
#     Diamonds  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 5          6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 6          7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# 7          8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
# 8          9   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78
# 9         10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05
# 10        11   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28
# ...

# %%
diamond3 = diamond2.corr()

# %%
sns.heatmap(diamond3)

# %%
sns.pairplot(diamond2,hue='carat',kind='reg')

# %%
plt.plot(diamond)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-3d2d96f14789> in <module>()
# ----> 1 plt.plot(diamond)
#
# c:\users\test\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# c:\users\test\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ...
