# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.read_csv('C:\\Users\\test\\Desktop\\Data\\HindAlu.csv')
# Out:
#            Date     INGOT INV NO  Coil No  Weight  Hidden Value 1  LENGTH  \
# 0     10/8/2017  DHDDR 170000163  EC-9536   251.0           94.65    1249
# 1     10/8/2017  DHDDR 170000163  EC-9537   255.0           95.32    1260
# 2     10/8/2017  DHDDR 170000163  EC-9538   277.0           95.37    1368
# 3     10/8/2017  DHDDR 170000163  EC-9539   252.0           94.95    1250
# 4     10/8/2017  DHDDR 170000163  EC-9540   251.0           95.18    1242
# 5     10/8/2017  DHDDR 170000168  EC-9541   248.0           94.89    1231
# 6     10/8/2017  DHDDR 170000163  EC-9542   253.0           95.18    1252
# 7     10/8/2017  DHDDR 170000163  EC-9543   252.0           95.49    1243
# 8     11/8/2017  DHDDR 170000163  EC-9544   264.0           94.48    1316
# 9     11/8/2017  DHDDR 170000163  EC-9545   236.0           95.16    1168
# 10    11/8/2017  DHDDR 170000167  EC-9546   241.0           94.59    1200
# 11    11/8/2017  DHDDR 170000167  EC-9547   241.0           95.22    1192
# ...

# %%
HindAlu = pd.read_csv('C:\\Users\\test\\Desktop\\Data\\HindAlu.csv',parse_dates = True, index_col='Date')

# %%
HindAlu
# Out:
#                INGOT INV NO  Coil No  Weight  Hidden Value 1  LENGTH  ALU ROD  \
# Date
# 2017-10-08  DHDDR 170000163  EC-9536   251.0           94.65    1249    9.729
# 2017-10-08  DHDDR 170000163  EC-9537   255.0           95.32    1260    9.763
# 2017-10-08  DHDDR 170000163  EC-9538   277.0           95.37    1368    9.766
# 2017-10-08  DHDDR 170000163  EC-9539   252.0           94.95    1250    9.744
# 2017-10-08  DHDDR 170000163  EC-9540   251.0           95.18    1242    9.756
# 2017-10-08  DHDDR 170000168  EC-9541   248.0           94.89    1231    9.741
# 2017-10-08  DHDDR 170000163  EC-9542   253.0           95.18    1252    9.756
# 2017-10-08  DHDDR 170000163  EC-9543   252.0           95.49    1243    9.772
# 2017-11-08  DHDDR 170000163  EC-9544   264.0           94.48    1316    9.720
# 2017-11-08  DHDDR 170000163  EC-9545   236.0           95.16    1168    9.755
# 2017-11-08  DHDDR 170000167  EC-9546   241.0           94.59    1200    9.726
# ...

# %%
print(HindAlu.shape)
# Out:
# (1940, 20)

# %%
HindAlu.plot(x='LENGTH', y='B_L')

# %%
HindAlu.plot(x='LENGTH', y='B_L', kind='scatter')
plt.xlabel('LENGTH')
plt.ylabel('B_L')
plt.show()

# %%
HindAlu.plot(y='LENGTH', kind='box')

# %%
HindAlu.plot(y='LENGTH', kind='hist')

# %%
HindAlu.plot(y='LENGTH', kind='bar')

# %%
Hind1 = HindAlu.head(10)

# %%
Hind1
# Out:
#                INGOT INV NO  Coil No  Weight  Hidden Value 1  LENGTH  ALU ROD  \
# Date
# 2017-10-08  DHDDR 170000163  EC-9536   251.0           94.65    1249    9.729
# 2017-10-08  DHDDR 170000163  EC-9537   255.0           95.32    1260    9.763
# 2017-10-08  DHDDR 170000163  EC-9538   277.0           95.37    1368    9.766
# 2017-10-08  DHDDR 170000163  EC-9539   252.0           94.95    1250    9.744
# 2017-10-08  DHDDR 170000163  EC-9540   251.0           95.18    1242    9.756
# 2017-10-08  DHDDR 170000168  EC-9541   248.0           94.89    1231    9.741
# 2017-10-08  DHDDR 170000163  EC-9542   253.0           95.18    1252    9.756
# 2017-10-08  DHDDR 170000163  EC-9543   252.0           95.49    1243    9.772
# 2017-11-08  DHDDR 170000163  EC-9544   264.0           94.48    1316    9.720
# 2017-11-08  DHDDR 170000163  EC-9545   236.0           95.16    1168    9.755
#
#             B_L    UTS  Elong    Area  Room Temp  Resistivity  Hidden Value 2  \
# Date
# ...

# %%
Hind1.plot(y='LENGTH', kind='box')

# %%
Hind1.plot(y='LENGTH', kind='bar')

# %%
Hind1.plot(y='LENGTH', kind='hist')

# %%
Hind1.plot(x='LENGTH', y='Weight', kind='scatter')
plt.xlabel('LENGTH')
plt.ylabel('Weight')
plt.show()

# %%
Hind1.plot(x='LENGTH', y='B_L')

# %%
Hind1.min()
# Out:
# INGOT INV NO        DHDDR 170000163
# Coil No                     EC-9536
# Weight                          236
# Hidden Value 1                94.48
# LENGTH                         1168
# ALU ROD                        9.72
# B_L                             836
# UTS                           11.24
# Elong                           8.4
# Area                         74.217
# Room Temp                        27
# Resistivity                  27.856
# Hidden Value 2                1.028
# Resistance at 1M              0.383
# Conductivity                  61.62
# Operator Name                CHANDU
# HIGH_H/SOFT_S                     H
# Joints                    No Joints
# Surface Finish               Smooth
# WRAP TEST                        OK
# dtype: object

# %%
Hind1.max()
# Out:
# INGOT INV NO        DHDDR 170000168
# Coil No                     EC-9545
# Weight                          277
# Hidden Value 1                95.49
# LENGTH                         1368
# ALU ROD                       9.772
# B_L                             887
# UTS                           11.85
# Elong                            10
# Area                         75.004
# Room Temp                        29
# Resistivity                  27.981
# Hidden Value 2                1.036
# Resistance at 1M               0.39
# Conductivity                  61.89
# Operator Name               RAJESH
# HIGH_H/SOFT_S                     H
# Joints                    No Joints
# Surface Finish               Smooth
# WRAP TEST                        OK
# dtype: object

# %%
Hind1.plot(kind='bar')

# %%
Hind1.plot(kind='hist')

# %%
HindAlu.loc['2017-10-08','LENGTH']
# Out:
# Date
# 2017-10-08    1249
# 2017-10-08    1260
# 2017-10-08    1368
# 2017-10-08    1250
# 2017-10-08    1242
# 2017-10-08    1231
# 2017-10-08    1252
# 2017-10-08    1243
# Name: LENGTH, dtype: int64

# %%
HindAlu.loc['2017-10-08']
# Out:
#                INGOT INV NO  Coil No  Weight  Hidden Value 1  LENGTH  ALU ROD  \
# Date
# 2017-10-08  DHDDR 170000163  EC-9536   251.0           94.65    1249    9.729
# 2017-10-08  DHDDR 170000163  EC-9537   255.0           95.32    1260    9.763
# 2017-10-08  DHDDR 170000163  EC-9538   277.0           95.37    1368    9.766
# 2017-10-08  DHDDR 170000163  EC-9539   252.0           94.95    1250    9.744
# 2017-10-08  DHDDR 170000163  EC-9540   251.0           95.18    1242    9.756
# 2017-10-08  DHDDR 170000168  EC-9541   248.0           94.89    1231    9.741
# 2017-10-08  DHDDR 170000163  EC-9542   253.0           95.18    1252    9.756
# 2017-10-08  DHDDR 170000163  EC-9543   252.0           95.49    1243    9.772
#
#             B_L    UTS  Elong    Area  Room Temp  Resistivity  Hidden Value 2  \
# Date
# 2017-10-08  836  11.24    8.8  74.347       28.0       27.952           1.032
# 2017-10-08  887  11.85    8.8  74.873       28.0       27.932           1.032
# ...

# %%
Hind1['LENGTH'].plot()
plt.show()

# %%
Hind1['LENGTH'].plot(title='HindAluminium Rod length')
plt.show()

# %%
HindAlu.loc['2017-10-08'].plot('LENGTH',kind='bar')

# %%
Hind1.plot(y='LENGTH', kind='area')

# %%
Hind1.loc['2017',['Weight','LENGTH']].plot()

# %%
Hind1.loc['2017',['Weight','LENGTH']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F2A4470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000104EE8D0>], dtype=object)

# %%
HindAlu['LENGTH'] > 1200
# Out:
# Date
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-10-08     True
# 2017-11-08     True
# 2017-11-08    False
# 2017-11-08    False
# 2017-11-08    False
# 2017-11-08    False
# 2017-11-08    False
# 2017-11-08     True
# 2017-11-08     True
# 2017-11-08     True
# 2017-12-08     True
# 2017-12-08    False
# 2017-12-08     True
# 2017-12-08     True
# 2017-12-08    False
# 2017-12-08    False
# 2017-12-08     True
# 2017-12-08    False
# 2017-12-08    False
# 2017-12-08    False
# 2017-08-17     True
# 2017-08-17     True
# 2017-08-17    False
#               ...
# 2018-02-01    False
# 2018-02-01    False
# 2018-02-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01    False
# 2018-03-01     True
# ...
